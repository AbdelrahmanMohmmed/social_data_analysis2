# %%
pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.2 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %%
all_reviews = []
continuation_token = None

# Fetch in batches
for _ in range(5):  # 5 batches x 200 = 1000 reviews
    result, continuation_token = reviews(
        'com.einnovation.temu',
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=200,
        continuation_token=continuation_token
    )
    all_reviews.extend(result)
    if not continuation_token:
        break

# Convert to DataFrame
df = pd.DataFrame(all_reviews)[['userName', 'score', 'content', 'at', 'thumbsUpCount']]
df.to_csv('temu_reviews.csv', index=False)
print(f"Saved {len(df)} reviews")
print("Shape: " ,df.shape)
# Out:
# Saved 1000 reviews
# Shape:  (1000, 5)

# %%
df.head()
# Out:
#           userName  score                                            content  \
# 0  Arden Parmenter      5                         so far it's great shopping
# 1   suzanne tehako      5  have been very happy with purchases. Thanks, T...
# 2    Maikol Maikol      1  I can't see a menu you keep blowing with spin ...
# 3  Asokere Edayomi      5  You are improving in your daily transactions. ...
# 4              J C      2  I've found a few fantastic products the rest a...
#
#                    at  thumbsUpCount
# 0 2026-03-08 19:33:09              0
# 1 2026-03-08 19:33:06              0
# 2 2026-03-08 19:31:26              0
# 3 2026-03-08 19:31:18              0
# 4 2026-03-08 19:30:18              0

# %%
all_reviews = []
continuation_token = None

# Fetch in batches
for _ in range(5):  # 5 batches x 200 = 1000 reviews
    result, continuation_token = reviews(
        'com.amazon.mShop.android.shopping',
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=200,
        continuation_token=continuation_token
    )
    all_reviews.extend(result)
    if not continuation_token:
        break

# Convert to DataFrame
df = pd.DataFrame(all_reviews)[['userName', 'score', 'content', 'at', 'thumbsUpCount']]
df.to_csv('amzon_reviews.csv', index=False)
print(f"Saved {len(df)} reviews")
print("Shape: " ,df.shape)
# Out:
# Saved 1000 reviews
# Shape:  (1000, 5)

# %%
df.head()
# Out:
#              userName  score  \
# 0            Tomislav      1
# 1       Andrea Carter      5
# 2    Mackenzie Feeley      1
# 3       Nunaya Bidnez      4
# 4  Christopher Kovacs      1
#
#                                              content                  at  \
# 0  very bad and laggy app, had big problems with ... 2026-03-08 19:33:25
# 1                  Love, Love Love these earrings ❤️ 2026-03-08 19:25:24
# 2  app if crashing ever since last update. cleare... 2026-03-08 19:20:08
# 3  Just over the last couple weeks the Amazon app... 2026-03-08 19:18:32
# 4  Lies about shipping frequently to get you to p... 2026-03-08 19:15:28
#
#    thumbsUpCount
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
all_reviews = []
continuation_token = None

# Fetch in batches
for _ in range(5):  # 5 batches x 200 = 1000 reviews
    result, continuation_token = reviews(
        'com.noon.buyerapp',
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=200,
        continuation_token=continuation_token
    )
    all_reviews.extend(result)
    if not continuation_token:
        break

# Convert to DataFrame
df = pd.DataFrame(all_reviews)[['userName', 'score', 'content', 'at', 'thumbsUpCount']]
df.to_csv('noon_reviews.csv', index=False)
print(f"Saved {len(df)} reviews")
print("Shape: " ,df.shape)
# Out:
# Saved 1000 reviews
# Shape:  (1000, 5)

# %%
df.head()
# Out:
#             userName  score                                       content  \
# 0       Kwesi Appiah      5            Very reliable and fastest delivery
# 1     MD:Nayem ISlAM      5                                     very good
# 2        Mir Hossain      5                                             👍
# 3  Thusanthan Thilak      5  it's my first order but I feel better thanks
# 4      Haneen Dawoud      5                                          good
#
#                    at  thumbsUpCount
# 0 2026-03-08 19:37:38              0
# 1 2026-03-08 18:44:07              0
# 2 2026-03-08 18:23:38              0
# 3 2026-03-08 18:06:56              0
# 4 2026-03-08 17:39:25              0

# %%
all_reviews = []
continuation_token = None

# Fetch in batches
for _ in range(5):  # 5 batches x 200 = 1000 reviews
    result, continuation_token = reviews(
        'com.alibaba.aliexpresshd',
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=200,
        continuation_token=continuation_token
    )
    all_reviews.extend(result)
    if not continuation_token:
        break

# Convert to DataFrame
df = pd.DataFrame(all_reviews)[['userName', 'score', 'content', 'at', 'thumbsUpCount']]
df.to_csv('ali-express_reviews.csv', index=False)
print(f"Saved {len(df)} reviews")
print("Shape: " ,df.shape)
# Out:
# Saved 1000 reviews
# Shape:  (1000, 5)

# %%
df.head()
# Out:
#              userName  score  \
# 0  sathish malamkunnu      1
# 1              Patryk      1
# 2           Rick Hess      5
# 3         Bertha Mata      5
# 4        Lion Soldier      3
#
#                                              content                  at  \
# 0  What is this? What a price for the goods. temu... 2026-03-08 19:31:38
# 1  Na stronie z punktami, pokazują się losowe zni... 2026-03-08 17:43:07
# 2  so far everything I have ordered has been fine... 2026-03-08 17:14:09
# 3  i love them i will continue to order from here... 2026-03-08 17:08:19
# 4  Title: Great app, but impossible to pay in Gha... 2026-03-08 17:03:02
#
#    thumbsUpCount
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
